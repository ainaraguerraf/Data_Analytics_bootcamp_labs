# %% [markdown]
# # <span style="color:rgb(255, 0, 255)"> Lab | API wrappers - Create your collection of songs & audio features
#
# <span style="color:rgb(255, 0, 255)"> Ainara Guerra
#
# Instructions
#
# To move forward with the project, you need to create a collection of songs with their audio features - as large as possible!
#
# These are the songs that we will cluster. And, later, when the user inputs a song, we will find the cluster to which the song belongs and recommend a song from the same cluster. The more songs you have, the more accurate and diverse recommendations you'll be able to give. Although... you might want to make sure the collected songs are "curated" in a certain way. Try to find playlists of songs that are diverse, but also that meet certain standards.
#
# The process of sending hundreds or thousands of requests can take some time - it's normal if you have to wait a few minutes (or, if you're ambitious, even hours) to get all the data you need.
#
# An idea for collecting as many songs as possible is to start with all the songs of a big, diverse playlist and then go to every artist present in the playlist and grab every song of every album of that artist. The amount of songs you'll be collecting per playlist will grow exponentially!

# %%
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="af3a4e21d9974f798b0ddef081728f2b",
                                                           client_secret="99a65d20eff04d64bcf24b11824dffc4"))

# mine spotify didn't work so i need to use Xisca's

# %% [markdown]
# ## User playlists

# %%
playlist = sp.user_playlist_tracks("spotify", "37i9dQZEVXbMDoHDwVN2tF")
playlist#.keys() # Let's look at items and total:
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbMDoHDwVN2tF/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2023-06-27T09:28:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0XeEobZplHxzM9QzFQWLiR'},
#        'href': 'https://api.spotify.com/v1/artists/0XeEobZplHxzM9QzFQWLiR',
#        'id': '0XeEobZplHxzM9QzFQWLiR',
#        'name': 'Eslabon Armado',
#        'type': 'artist',
#        'uri': 'spotify:artist:0XeEobZplHxzM9QzFQWLiR'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
# ...

# %%
playlist["total"]
# Out:
# 50

# %%
len(playlist["items"])
# Out:
# 50

# %% [markdown]
# ### How to get all the songs from a playlist?

# %%
### OPTION 1
results = sp.user_playlist_tracks("spotify", "37i9dQZEVXbMDoHDwVN2tF")
tracks = results['items']

while results['next']:
    results = sp.next(results)
    tracks.extend(results['items'])
len(tracks)
# Out:
# 50

# %%
### CREATE A FUNCTION TO SOLVE THE ISSUE
# It is limited to 100 tracks, we will have to fix it:

def get_playlist_tracks(username, playlist_id):
    
    results = sp.user_playlist_tracks(username, playlist_id)
    tracks = results['items']
    
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    
    return tracks

tracks = get_playlist_tracks("spotify", "37i9dQZEVXbMDoHDwVN2tF")

# %%
tracks#[0]['track']#['artists']#.keys()#['name']
# Out:
# [{'added_at': '2023-06-27T09:28:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0XeEobZplHxzM9QzFQWLiR'},
#       'href': 'https://api.spotify.com/v1/artists/0XeEobZplHxzM9QzFQWLiR',
#       'id': '0XeEobZplHxzM9QzFQWLiR',
#       'name': 'Eslabon Armado',
#       'type': 'artist',
#       'uri': 'spotify:artist:0XeEobZplHxzM9QzFQWLiR'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
# ...

# %%
len(tracks)
# Out:
# 50

# %% [markdown]
# ### First: How to get all the artists that appear in a playlist?

# %%
# Getting all the artists

def get_artists_from_playlist(playlist_id):
    
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    
    artists = []
    
    for track in tracks_from_playlist:
        artists_info = track['track']['artists']
        
        for artist_info in artists_info:
            artists.append(artist_info['name'])
    
    return list(set(artists))

# %%
artists = get_artists_from_playlist("37i9dQZEVXbMDoHDwVN2tF")
artists
# Out:
# ['Duki',
#  'Bizarrap',
#  'Big One',
#  'Gunna',
#  'Young Miko',
#  'Libianca',
#  'Daft Punk',
#  'Metro Boomin',
#  'Jimin',
#  'A$AP Rocky',
#  'FMK',
#  'FIFTY FIFTY',
#  'The Weeknd',
#  'Kali Uchis',
#  'Playboi Carti',
#  'Yng Lvcas',
#  'Miley Cyrus',
#  'Dave',
#  'Post Malone',
#  'Grupo Frontera',
#  'Junior H',
#  'Fuerza Regida',
#  'Morgan Wallen',
#  '21 Savage',
#  'Feid',
#  'Emilia',
#  'Sky Rompiendo',
#  'LIT killah',
#  'Shakira',
#  'Rema',
#  'Taylor Swift',
#  'NAV',
#  'Aqua',
#  'Bebe Rexha',
#  'KAROL G',
#  'Eslabon Armado',
#  'OneRepublic',
#  'Harry Styles',
#  'Ariana Grande',
#  'Tom Odell',
#  'MC Kevin o Chris',
#  'DENNIS',
#  'Tiago PZK',
#  'Ice Spice',
#  'Rauw Alejandro',
#  'Bad Bunny',
#  'Selena Gomez',
#  'Yahritza Y Su Esencia',
#  'Gabito Ballesteros',
#  'Roisee',
#  'Tyler, The Creator',
#  'David Kushner',
#  'Rusherking',
#  'ROSALÍA',
#  'Swae Lee',
#  'Maria Becerra',
#  'Arctic Monkeys',
#  'David Guetta',
#  'Peso Pluma',
# ...

# %% [markdown]
# ### Second: How to get all the artists ids from artists appearing in a playlist?

# %%
# Getting all the artists IDs

def get_artists_ids_from_playlist(playlist_id):
    
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    
    artists_ids = []
    
    for track in tracks_from_playlist:
        artists_info = track['track']['artists']
        
        for artist_info in artists_info:
            artists_ids.append(artist_info['id'])
            
    return list(set(artists_ids))

# %%
artists_ids = get_artists_ids_from_playlist("37i9dQZEVXbMDoHDwVN2tF")
artists_ids
# Out:
# ['1URnnhqYAYcrqrcwql10ft',
#  '06HL4z0CvFAxyc27GXpf02',
#  '5H4yInM5zmHqpKIoMNAx4r',
#  '4GJ6xDCF5jaUqD6avOuQT6',
#  '6tbjWDEIzxoDsBA1FuhfPW',
#  '6Sbl0NT50roqWvy746MfVf',
#  '699OTQXzgjhIYAHMy9RyPD',
#  '0ys2OFYzWYB5hRDLCsBqxt',
#  '246dkjvS1zLTtiykXe5h60',
#  '790FomKkXshlbRYZFtlgla',
#  '1zNqQNIdeOUZHb8zbZRFMX',
#  '6KImCVD70vtIoJWnq6nGn3',
#  '0C8ZW7ezQVs4URX5aX7Kqx',
#  '5pCGvSxNNUcddlRrG0wsrY',
#  '7rkW85dBwwrJtlHRDkJDAC',
#  '3Nrfpe0tUJi4K4DXYWgMUX',
#  '6xlRSRMLgZbsSNd0BMobwy',
#  '5Pwc4xIPtQLFEnJriah9YJ',
#  '2LRoIwlKmHjgvigdNGBHNo',
#  '1Cs0zKBU1kc0i8ypK3B9ai',
#  '33NVpKoXjItPwUJTMZIOiY',
#  '0hCNtLu0JehylgoiP8L4Gh',
#  '5YGY8feqx7naU7z4HrwZM6',
#  '1Xyo4u8uXC1ZmMpatF05PJ',
#  '64M6ah0SkkRsnPGtGiRAbb',
#  '6XkjpgcEsYab502Vr1bBeW',
#  '4tZwfgrHOc3mvqYlEYSvVi',
#  '0XeEobZplHxzM9QzFQWLiR',
#  '0AqlFI0tz2DsEoJlKSIiT9',
#  '7iK8PXO48WeuP03g8YR51W',
#  '1vqR17Iv8VFdzure1TAXEq',
#  '7tYKF4w9nC0nq9CsPZTHyP',
#  '3Apb2lGmGJaBmr0TTBJvIZ',
#  '3LZZPxNDGDFVSIPqf4JuEf',
# ...

# %% [markdown]
# ### Activity 3: Put the two functions above in one

# %% [markdown]
# ### Activity 4: Take a list of Track Ids from the songs in a playlist

# %%
track_ids = [track['track']['id'] for track in tracks]
track_ids
# Out:
# ['3qQbCzHBycnDpGskqOWY0E',
#  '7ro0hRteUMfnOioTFI5TG1',
#  '1BxfuPKGuaTgP7aM0Bbdwr',
#  '6pD0ufEQq0xdHSsRbg9LBK',
#  '2UW7JaomAMuX9pZrjVpHAU',
#  '1odExI7RdWc4BT515LTAwj',
#  '4DHcnVTT87F0zZhRPYmZ3B',
#  '2FDTHlrBguDzQkp7PVj16Q',
#  '4Dvkj6JhhA12EX05fT7y2e',
#  '7FbrGaHYVDmfr7KoLIZnQ7',
#  '0WCxpmafw3tOlUmiilGbsy',
#  '1Qrg8KqiBpW07V7PNxwwwL',
#  '2NFadq6pUeiVEihLvUlOSr',
#  '5AqiaZwhmC6dIbgWrD5SzV',
#  '1UMm1Qs3u59Wvk53zBUE8r',
#  '4I1OcJiqk279qLaI2OAecB',
#  '0RiRZpuVRbi7oqRdSMwhQY',
#  '5XeFesFbtLpXzIVDNQP22n',
#  '368eeEO3Y2uZUQ6S5oIjcu',
#  '6XSqqQIy7Lm7SnwxS4NrGx',
#  '1Hs1uUl8o2VtDp1DABFq0O',
#  '1s7oOCT8vauUh01PbJD6ps',
#  '4PA1wK0leCjmRZlP5dQ8Lv',
#  '1daDRI9ahBonbWD8YcxOIB',
#  '2dHHgzDwk4BJdRwy9uXhTO',
#  '0V3wPSX9ygBnCm8psDIegu',
#  '0DWdj2oZMBFSzRsi2Cvfzf',
#  '3Ua0m0YmEjrMi9XErKcNiR',
#  '7KA4W4McWYRpgf0fWsJZWB',
#  '5rurggqwwudn9clMdcchxT',
#  '7K3BhSpAxZBznislvUMVtn',
#  '2LBqCSwhJGcFQeTHMVGwy3',
#  '4uUG5RXrOk84mYEfFvj3cK',
#  '741UUVE2kuITl0c6zuqqbO',
# ...

# %% [markdown]
# ### Now we need the features for our prototype

# %%
sp.audio_features(track_ids[:100]) ## [0] ### There is a limit of 100 songs
# Out:
# [{'danceability': 0.668,
#   'energy': 0.758,
#   'key': 5,
#   'loudness': -5.176,
#   'mode': 0,
#   'speechiness': 0.0332,
#   'acousticness': 0.483,
#   'instrumentalness': 1.89e-05,
#   'liveness': 0.0837,
#   'valence': 0.834,
#   'tempo': 147.989,
#   'type': 'audio_features',
#   'id': '3qQbCzHBycnDpGskqOWY0E',
#   'uri': 'spotify:track:3qQbCzHBycnDpGskqOWY0E',
#   'track_href': 'https://api.spotify.com/v1/tracks/3qQbCzHBycnDpGskqOWY0E',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3qQbCzHBycnDpGskqOWY0E',
#   'duration_ms': 165671,
#   'time_signature': 3},
#  {'danceability': 0.652,
#   'energy': 0.8,
#   'key': 9,
#   'loudness': -4.019,
#   'mode': 0,
#   'speechiness': 0.0614,
#   'acousticness': 0.143,
#   'instrumentalness': 0.629,
#   'liveness': 0.112,
#   'valence': 0.234,
#   'tempo': 143.978,
#   'type': 'audio_features',
#   'id': '7ro0hRteUMfnOioTFI5TG1',
#   'uri': 'spotify:track:7ro0hRteUMfnOioTFI5TG1',
# ...

# %% [markdown]
# ### Let's put it in a dataframe!!

# %%
feat = sp.audio_features(track_ids[:100]) ## [0] ### There is a limit of 100 songs
df = pd.DataFrame(feat)
df
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.668   0.758    5    -5.176     0       0.0332       0.48300
# 1          0.652   0.800    9    -4.019     0       0.0614       0.14300
# 2          0.552   0.702    9    -5.707     1       0.1570       0.11700
# 3          0.569   0.724    6    -4.076     0       0.0474       0.22800
# 4          0.812   0.479    2    -5.678     0       0.3330       0.21300
# 5          0.508   0.430    2    -9.475     0       0.0335       0.83000
# 6          0.707   0.681    0    -4.325     1       0.0668       0.06320
# 7          0.916   0.583    1    -8.067     1       0.2410       0.18600
# 8          0.520   0.731    6    -5.338     0       0.0557       0.34200
# 9          0.783   0.592   11    -8.332     0       0.0331       0.43500
# 10         0.646   0.736    5    -7.118     0       0.0449       0.21600
# 11         0.644   0.735    8    -5.747     1       0.0391       0.05210
# ...
