# %% [markdown]
# # Lab | Customer Analysis Round 1
# ## Ainara Guerra

# %% [markdown]
# #### 1. Read the three files into python as dataframesb

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('file1.csv')
df1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df2 = pd.read_csv('file2.csv')
df2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
df3 = pd.read_csv('file3.csv')
df3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %% [markdown]
# #### 2. Show the DataFrame's shape.

# %%
df1.shape
# Out:
# (4008, 11)

# %%
df2.shape
# Out:
# (996, 11)

# %%
df3.shape
# Out:
# (7070, 11)

# %% [markdown]
# #### 3. Standardize header names.

# %%
df3 = df3.rename(columns={'State': 'ST'})

# %%
cols1 = [col_name.lower().replace(' ', '_') for col_name in df1]
cols1
# Out:
# ['customer',
#  'st',
#  'gender',
#  'education',
#  'customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'policy_type',
#  'vehicle_class',
#  'total_claim_amount']

# %%
cols2 = [col_name.lower().replace(' ', '_') for col_name in df2]
cols2
# Out:
# ['customer',
#  'st',
#  'gender',
#  'education',
#  'customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'total_claim_amount',
#  'policy_type',
#  'vehicle_class']

# %%
cols3 = [col_name.lower().replace(' ', '_') for col_name in df3]
cols3
# Out:
# ['customer',
#  'st',
#  'customer_lifetime_value',
#  'education',
#  'gender',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'policy_type',
#  'total_claim_amount',
#  'vehicle_class']

# %%
df1.columns = cols1
df1.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount'],
#       dtype='object')

# %%
df1.head()
# Out:
#   customer          st gender             education customer_lifetime_value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
df2.columns = cols2
df2.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'total_claim_amount', 'policy_type', 'vehicle_class'],
#       dtype='object')

# %%
df2.head()
# Out:
#   customer          st gender education customer_lifetime_value  income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       policy_type  vehicle_class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
df3.columns = cols3
df3.columns
# Out:
# Index(['customer', 'st', 'customer_lifetime_value', 'education', 'gender',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'total_claim_amount', 'vehicle_class'],
#       dtype='object')

# %%
df3.head()
# Out:
#   customer          st  customer_lifetime_value             education gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    income  monthly_premium_auto  number_of_open_complaints    policy_type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    total_claim_amount  vehicle_class
# ...

# %% [markdown]
# #### 3. Rearrange the columns in the dataframe as needed

# %%
df1_ordered = df1[['customer',
 'st',
 'gender',
 'education',
 'customer_lifetime_value',
 'income',
 'monthly_premium_auto',
 'number_of_open_complaints',
 'policy_type',
 'vehicle_class',
 'total_claim_amount']]
df1_ordered
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df2_ordered = df2[['customer',
 'st',
 'gender',
 'education',
 'customer_lifetime_value',
 'income',
 'monthly_premium_auto',
 'number_of_open_complaints',
 'policy_type',
 'vehicle_class',
 'total_claim_amount']]
df2_ordered
# Out:
#     customer          st gender education customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly_premium_auto number_of_open_complaints     policy_type  \
# ...

# %%
df3_ordered = df3[['customer',
 'st',
 'gender',
 'education',
 'customer_lifetime_value',
 'income',
 'monthly_premium_auto',
 'number_of_open_complaints',
 'policy_type',
 'vehicle_class',
 'total_claim_amount']]
df3_ordered
# Out:
#      customer          st gender             education  \
# 0     SA25987  Washington      M  High School or Below
# 1     TB86706     Arizona      M                Master
# 2     ZL73902      Nevada      F              Bachelor
# 3     KX23516  California      F  High School or Below
# 4     FN77294  California      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 3479.137523       0                   104
# 1                 2502.637401       0                    66
# 2                 3265.156348   25820                    82
# ...

# %% [markdown]
# #### 4. Concatenate the three dataframes

# %%
all_data = pd.concat([df1,df2,df3])
all_data
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %% [markdown]
# #### 5. Which columns are numerical?

# %%
all_data.describe()
#But this isnt't true because it gets some columns as objects that are numerical,so, correct answer:
# inocme, monthly_premium_auto_total_claim_amount, customer_lifetime_value, number_of_open_complaints
# Out:
#              income  monthly_premium_auto  total_claim_amount
# count   9137.000000           9137.000000         9137.000000
# mean   37828.820291            110.391266          430.527140
# std    30358.716159            581.376032          289.582968
# min        0.000000             61.000000            0.099007
# 25%        0.000000             68.000000          266.996814
# 50%    34244.000000             83.000000          377.561463
# 75%    62447.000000            109.000000          546.420009
# max    99981.000000          35354.000000         2893.239678

# %% [markdown]
# #### 6. Which columns are categorical?

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   9137 non-null   object
#  1   st                         9137 non-null   object
#  2   gender                     9015 non-null   object
#  3   education                  9137 non-null   object
#  4   customer_lifetime_value    9130 non-null   object
#  5   income                     9137 non-null   float64
#  6   monthly_premium_auto       9137 non-null   float64
#  7   number_of_open_complaints  9137 non-null   object
#  8   policy_type                9137 non-null   object
#  9   vehicle_class              9137 non-null   object
#  10  total_claim_amount         9137 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 1.1+ MB

# %% [markdown]
# #### 7. Understand the meaning of all columns

# %% [markdown]
# #### 8. Perform the data cleaning operations mentioned so far in class

# %% [markdown]
# #### 8.1. Delete the column education and the number of open complaints from the dataframe.

# %%
all_data.drop(['education','number_of_open_complaints'], axis='columns', inplace=True)
all_data.head()
# Out:
#   customer          st gender customer_lifetime_value   income  \
# 0  RB50392  Washington    NaN                     NaN      0.0
# 1  QZ44356     Arizona      F              697953.59%      0.0
# 2  AI49188      Nevada      F             1288743.17%  48767.0
# 3  WW63253  California      M              764586.18%      0.0
# 4  GA49547  Washington      M              536307.65%  36357.0
#
#    monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                1000.0   Personal Auto  Four-Door Car            2.704934
# 1                  94.0   Personal Auto  Four-Door Car         1131.464935
# 2                 108.0   Personal Auto   Two-Door Car          566.472247
# 3                 106.0  Corporate Auto            SUV          529.881344
# 4                  68.0   Personal Auto  Four-Door Car           17.269323

# %% [markdown]
# #### 8.2. Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.

# %%
all_data["customer_lifetime_value"] = all_data["customer_lifetime_value"].apply(lambda x: str(x))
all_data["customer_lifetime_value"] = all_data["customer_lifetime_value"].apply(lambda x: x.replace("%", ""))
all_data["customer_lifetime_value"] = all_data["customer_lifetime_value"].astype(float)
all_data['customer_lifetime_value'] = all_data['customer_lifetime_value'].replace(np.nan, 0)
all_data
# Out:
#      customer          st gender  customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN             0.000000e+00      0.0
# 1     QZ44356     Arizona      F             6.979536e+05      0.0
# 2     AI49188      Nevada      F             1.288743e+06  48767.0
# 3     WW63253  California      M             7.645862e+05      0.0
# 4     GA49547  Washington      M             5.363077e+05  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M             2.340599e+04  71941.0
# 7066  PK87824  California      F             3.096511e+03  21604.0
# 7067  TD14365  California      M             8.163890e+03      0.0
# 7068  UP19263  California      M             7.524442e+03  21941.0
# 7069  Y167826  California      M             2.611837e+03      0.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
all_data["customer_lifetime_value"] = all_data["customer_lifetime_value"].astype(str)
all_data["customer_lifetime_value"] = all_data["customer_lifetime_value"].apply(lambda x: x.replace("NaN", "0"))
all_data["customer_lifetime_value"] = all_data["customer_lifetime_value"].astype(float)
all_data.head()
# Out:
#   customer          st gender  customer_lifetime_value   income  \
# 0  RB50392  Washington    NaN                     0.00      0.0
# 1  QZ44356     Arizona      F                697953.59      0.0
# 2  AI49188      Nevada      F               1288743.17  48767.0
# 3  WW63253  California      M                764586.18      0.0
# 4  GA49547  Washington      M                536307.65  36357.0
#
#    monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                1000.0   Personal Auto  Four-Door Car            2.704934
# 1                  94.0   Personal Auto  Four-Door Car         1131.464935
# 2                 108.0   Personal Auto   Two-Door Car          566.472247
# 3                 106.0  Corporate Auto            SUV          529.881344
# 4                  68.0   Personal Auto  Four-Door Car           17.269323

# %%
all_data["customer_lifetime_value"].isna().sum()
#PROBLEM = I see I got everything right but the "fillna", so I am solving that, but it doesn't seem to work...
# Out:
# 0

# %%
all_data.head()
# Out:
#   customer          st gender  customer_lifetime_value   income  \
# 0  RB50392  Washington    NaN                     0.00      0.0
# 1  QZ44356     Arizona      F                697953.59      0.0
# 2  AI49188      Nevada      F               1288743.17  48767.0
# 3  WW63253  California      M                764586.18      0.0
# 4  GA49547  Washington      M                536307.65  36357.0
#
#    monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                1000.0   Personal Auto  Four-Door Car            2.704934
# 1                  94.0   Personal Auto  Four-Door Car         1131.464935
# 2                 108.0   Personal Auto   Two-Door Car          566.472247
# 3                 106.0  Corporate Auto            SUV          529.881344
# 4                  68.0   Personal Auto  Four-Door Car           17.269323

# %% [markdown]
# #### 8.3. Check for duplicate rows in the data and remove if any.

# %%
all_data = all_data.drop_duplicates()
all_data
# found here: https://www.statology.org/pandas-drop-duplicates/
# Out:
#      customer          st gender  customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN             0.000000e+00      0.0
# 1     QZ44356     Arizona      F             6.979536e+05      0.0
# 2     AI49188      Nevada      F             1.288743e+06  48767.0
# 3     WW63253  California      M             7.645862e+05      0.0
# 4     GA49547  Washington      M             5.363077e+05  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M             2.340599e+04  71941.0
# 7066  PK87824  California      F             3.096511e+03  21604.0
# 7067  TD14365  California      M             8.163890e+03      0.0
# 7068  UP19263  California      M             7.524442e+03  21941.0
# 7069  Y167826  California      M             2.611837e+03      0.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %% [markdown]
# #### 8.4. Filter out the data for customers who have an income of 0 or less.

# %%
low_income = all_data[all_data["income"]<=0]
low_income
# Out:
#      customer          st gender  customer_lifetime_value  income  \
# 0     RB50392  Washington    NaN                 0.000000     0.0
# 1     QZ44356     Arizona      F            697953.590000     0.0
# 3     WW63253  California      M            764586.180000     0.0
# 7     CF85061     Arizona      M            721610.030000     0.0
# 10    SX51350  California      M            473899.200000     0.0
# ...       ...         ...    ...                      ...     ...
# 7059  WZ45103  California      F              5678.050167     0.0
# 7061  RX91025  California      M             19872.262000     0.0
# 7062  AC13887  California      M              4628.995325     0.0
# 7067  TD14365  California      M              8163.890428     0.0
# 7069  Y167826  California      M              2611.836866     0.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %% [markdown]
# #### Plus. Other cleaning

# %%
all_data.isna().sum()
# Out:
# customer                     1
# st                           1
# gender                     123
# customer_lifetime_value      0
# income                       1
# monthly_premium_auto         1
# policy_type                  1
# vehicle_class                1
# total_claim_amount           1
# dtype: int64

# %%
all_data['gender'].value_counts()
# Out:
# F         4557
# M         4368
# Male        40
# female      30
# Femal       17
# Name: gender, dtype: int64

# %%
all_data["gender"] = all_data["gender"].apply(lambda x: str(x))
all_data["gender"] = all_data["gender"].apply(lambda x: x.replace("Male", "M"))
all_data["gender"] = all_data["gender"].apply(lambda x: x.replace("female", "F"))
all_data["gender"] = all_data["gender"].apply(lambda x: x.replace("femal", "F"))
all_data["gender"] = all_data["gender"].apply(lambda x: x.replace("Femal", "F"))
all_data["gender"] = all_data["gender"].apply(lambda x: x.replace("nan", "Unknown"))
all_data['gender'].value_counts()
# Out:
# F          4604
# M          4408
# Unknown     123
# Name: gender, dtype: int64

# %%
all_data["customer"] = all_data["customer"].fillna("Unknown")
all_data["st"] = all_data["st"].fillna("Unknown")
all_data["income"] = all_data["income"].fillna("Unknown")
all_data["monthly_premium_auto"] = all_data["monthly_premium_auto"].fillna("Unknown")
all_data["policy_type"] = all_data["policy_type"].fillna("Unknown")
all_data["vehicle_class"] = all_data["vehicle_class"].fillna("Unknown")
all_data["total_claim_amount"] = all_data["total_claim_amount"].fillna("Unknown")
all_data.isna().sum()
# Out:
# customer                   0
# st                         0
# gender                     0
# customer_lifetime_value    0
# income                     0
# monthly_premium_auto       0
# policy_type                0
# vehicle_class              0
# total_claim_amount         0
# dtype: int64

# %%
all_data["st"].value_counts()
# Out:
# California    3030
# Oregon        2601
# Arizona       1629
# Nevada         882
# Washington     768
# Cali           120
# AZ              74
# WA              30
# Unknown          1
# Name: st, dtype: int64

# %%
all_data["st"] = all_data["st"].apply(lambda x: str(x))
all_data["st"] = all_data["st"].apply(lambda x: x.replace("AZ", "Arizona"))
all_data["st"] = all_data["st"].apply(lambda x: x.replace("WA", "Washington"))
all_data["st"] = all_data["st"].apply(lambda x: x.replace("Cali ", "California"))
all_data["st"] = all_data["st"].apply(lambda x: x.replace("Californiafornia", "California"))
all_data["st"].value_counts()
# Out:
# California    3150
# Oregon        2601
# Arizona       1703
# Nevada         882
# Washington     798
# Unknown          1
# Name: st, dtype: int64

# %%
all_data.head()
# Out:
#   customer          st   gender  customer_lifetime_value   income  \
# 0  RB50392  Washington  Unknown                     0.00      0.0
# 1  QZ44356     Arizona        F                697953.59      0.0
# 2  AI49188      Nevada        F               1288743.17  48767.0
# 3  WW63253  California        M                764586.18      0.0
# 4  GA49547  Washington        M                536307.65  36357.0
#
#   monthly_premium_auto     policy_type  vehicle_class total_claim_amount
# 0               1000.0   Personal Auto  Four-Door Car           2.704934
# 1                 94.0   Personal Auto  Four-Door Car        1131.464935
# 2                108.0   Personal Auto   Two-Door Car         566.472247
# 3                106.0  Corporate Auto            SUV         529.881344
# 4                 68.0   Personal Auto  Four-Door Car          17.269323

# %%
all_data["policy_type"].value_counts()
#it's looking great, no changes needed
# Out:
# Personal Auto     6790
# Corporate Auto    1965
# Special Auto       379
# Unknown              1
# Name: policy_type, dtype: int64

# %%
all_data["vehicle_class"].value_counts()
#it also looks great
# Out:
# Four-Door Car    4640
# Two-Door Car     1895
# SUV              1773
# Sports Car        483
# Luxury SUV        182
# Luxury Car        161
# Unknown             1
# Name: vehicle_class, dtype: int64

# %%
all_data.to_csv('merged_clean_all_data.csv')

# %%
from IPython.display import HTML
HTML('<img src="https://media.giphy.com/media/uSYQsJQWEv6O4/giphy-downsized-large.gif">')
# Out:
# <img src="https://media.giphy.com/media/uSYQsJQWEv6O4/giphy-downsized-large.gif">

# %% [markdown]
# I hope it's not too bad 💗
